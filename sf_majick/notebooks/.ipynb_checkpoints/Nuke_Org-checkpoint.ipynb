# %%
import sf_magic as sfm
import requests
import json


sf = sfm.SalesforceLogin()

# %%
import requests

def delete_records_one_by_one(sf, object_api_name, record_ids, api_version="v59.0"):
    """
    Deletes Salesforce records individually using REST.
    """

    if not record_ids:
        print(f"No records to delete for {object_api_name}. Skipping.")
        return

    headers = sf.headers()

    for idx, record_id in enumerate(record_ids, start=1):
        url = f"{sf.instance_url}/services/data/{api_version}/sobjects/{object_api_name}/{record_id}"

        response = requests.delete(url, headers=headers)

        if response.status_code in (200, 204):
            print(f"✅ [{idx}/{len(record_ids)}] Deleted {object_api_name} {record_id}")
        else:
            print(
                f"❌ [{idx}/{len(record_ids)}] Failed deleting {object_api_name} {record_id}: "
                f"{response.status_code} {response.text}"
            )

# %%
# query = '''
# SELECT Id
# From Opportunity
# '''

# op_records, op_df = sfm.run_soql(query, sf)
# opportunity_ids = op_df['Id'].to_list()

# %%
query = '''
SELECT Id
From Contact
'''

contact_records, contact_df = sfm.run_soql(query, sf)
contact_ids = contact_df['Id'].to_list()

# %%
query = '''
SELECT Id
From Account
'''

account_records, account_df = sfm.run_soql(query, sf)
account_ids = account_df['Id'].to_list()

# %%
# delete_records_one_by_one(sf, "Opportunity", opportunity_ids)
delete_records_one_by_one(sf, "Contact", contact_ids)
delete_records_one_by_one(sf, "Account", account_ids)
# Out:
# ❌ [1/15] Failed deleting Contact 003ak000011OFXtAAO: 400 [{"message":"Your attempt to delete Ms. Rose Gonzalez could not be completed because it is associated with the following cases.: 00001000\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [2/15] Failed deleting Contact 003ak000011OFXuAAO: 400 [{"message":"Your attempt to delete Mr. Sean Forbes could not be completed because it is associated with the following cases.: 00001017, 00001018\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [3/15] Failed deleting Contact 003ak000011OFXvAAO: 400 [{"message":"Your attempt to delete Mr. Jack Rogers could not be completed because it is associated with the following cases.: 00001019, 00001020\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [4/15] Failed deleting Contact 003ak000011OFXyAAO: 400 [{"message":"Your attempt to delete Mr. Tim Barr could not be completed because it is associated with the following cases.: 00001007, 00001008\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [5/15] Failed deleting Contact 003ak000011OFXzAAO: 400 [{"message":"Your attempt to delete Mr. John Bond could not be completed because it is associated with the following cases.: 00001013, 00001014\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [6/15] Failed deleting Contact 003ak000011OFY0AAO: 400 [{"message":"Your attempt to delete Ms. Stella Pavlova could not be completed because it is associated with the following cases.: 00001002, 00001021, 00001022, 00001023\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [7/15] Failed deleting Contact 003ak000011OFY1AAO: 400 [{"message":"Your attempt to delete Ms. Lauren Boyle could not be completed because it is associated with the following cases.: 00001024, 00001025\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [8/15] Failed deleting Contact 003ak000011OFY2AAO: 400 [{"message":"Your attempt to delete Ms. Babara Levy could not be completed because it is associated with the following cases.: 00001003, 00001004\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [9/15] Failed deleting Contact 003ak000011OFY3AAO: 400 [{"message":"Your attempt to delete Mr. Josh Davis could not be completed because it is associated with the following cases.: 00001005\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [10/15] Failed deleting Contact 003ak000011OFY4AAO: 400 [{"message":"Your attempt to delete Mr. Tom Ripley could not be completed because it is associated with the following cases.: 00001010\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [11/15] Failed deleting Contact 003ak000011OFY5AAO: 400 [{"message":"Your attempt to delete Ms. Jane Grey could not be completed because it is associated with the following cases.: 00001012\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [12/15] Failed deleting Contact 003ak000011OFY7AAO: 400 [{"message":"Your attempt to delete Ms. Ashley James could not be completed because it is associated with the following cases.: 00001009\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [13/15] Failed deleting Contact 003ak000011OFY8AAO: 400 [{"message":"Your attempt to delete Ms. Liz D'Cruz could not be completed because it is associated with the following cases.: 00001011, 00001015\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [14/15] Failed deleting Contact 003ak000011OFY9AAO: 400 [{"message":"Your attempt to delete Ms. Edna Frank could not be completed because it is associated with the following cases.: 00001006, 00001016\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [15/15] Failed deleting Contact 003ak000011OFYAAA4: 400 [{"message":"Your attempt to delete Mr. Avi Green could not be completed because it is associated with the following cases.: 00001001\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [1/11] Failed deleting Account 001ak00001l9P3dAAE: 400 [{"message":"Your attempt to delete Edge Communications could not be completed because it is associated with the following cases.: 00001000, 00001017, 00001018\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [2/11] Failed deleting Account 001ak00001l9P3eAAE: 400 [{"message":"Your attempt to delete Burlington Textiles Corp of America could not be completed because it is associated with the following cases.: 00001019, 00001020\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [3/11] Failed deleting Account 001ak00001l9P3hAAE: 400 [{"message":"Your attempt to delete Grand Hotels & Resorts Ltd could not be completed because it is associated with the following cases.: 00001007, 00001008, 00001013, 00001014\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [4/11] Failed deleting Account 001ak00001l9P3iAAE: 400 [{"message":"Your attempt to delete United Oil & Gas Corp. could not be completed because it is associated with the following cases.: 00001001, 00001002, 00001021, 00001022, ..., ..., ...\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [5/11] Failed deleting Account 001ak00001l9P3jAAE: 400 [{"message":"Your attempt to delete Express Logistics and Transport could not be completed because it is associated with the following cases.: 00001003, 00001004, 00001005\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [6/11] Failed deleting Account 001ak00001l9P3kAAE: 400 [{"message":"Your attempt to delete United Oil & Gas, Singapore could not be completed because it is associated with the following cases.: 00001010, 00001011, 00001015\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [7/11] Failed deleting Account 001ak00001l9P3lAAE: 400 [{"message":"Your attempt to delete University of Arizona could not be completed because it is associated with the following cases.: 00001012\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [8/11] Failed deleting Account 001ak00001l9P3mAAE: 400 [{"message":"Your attempt to delete United Oil & Gas, UK could not be completed because it is associated with the following cases.: 00001009\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [9/11] Failed deleting Account 001ak00001l9P3nAAE: 400 [{"message":"Your attempt to delete GenePoint could not be completed because it is associated with the following cases.: 00001006, 00001016\n","errorCode":"DELETE_FAILED","fields":[]}]
# ❌ [10/11] Failed deleting Account 001ak00001l9P3pAAE: 400 [{"message":"Your attempt to delete Sample Account for Entitlements could not be completed because it is associated with the following entitlements.: Sample Entitlement\n","errorCode":"DELETE_FAILED","fields":[]}]
# ✅ [11/11] Deleted Account 001ak00001mQKJtAAO
